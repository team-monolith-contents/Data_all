# %% [markdown]
# <div class="alert alert-info">
#     <font color=black>
#     🙋 <b>Pandas, Pyplot</b>을 사용하기 위해서 다음 선언문을 실행하세요.
#     </font>
# </div>

# %%
import pandas as pd  # 판다스를 pd로 축약하여 불러옵니다.
import matplotlib.pyplot as plt  # Pyplot을 plt로 축약하여 불러옵니다.

# %% [markdown]
# # **[2] 꺾은선 그래프 겹쳐 그리기**
#
# [오늘 배울 것]
# 1. 꺾은선 그래프로 겹쳐서 나타낼 데이터를 고를 수 있다.
# 2. 꺾은선 그래프 여러개를 겹쳐 그릴 수 있다.

# %% [markdown]
# ##  **1. 꺾은선 그래프와 데이터**

# %% [markdown]
# ### **(1) 꺾은선 그래프로 겹쳐그리기 좋은 데이터**
#
# > 다음은 여러 지역의 일 별 코로나19 확진자 수를 꺾은선 그래프로 나타낸 것입니다.
# > 그래프를 통해 각 지역의 6개월 동안의 확진자 발생 추이(시간에 따라 변화하는 모습, 경향)를 한눈에 확인하고 비교할 수 있습니다.
# > 인구가 많은 순서(서울, 부산, 대구, 대전)로 일일 확진자 수 차이가 있지만 날짜에 따른 변화는 비슷함을 확인할 수 있습니다.
# >
# > ![image.png](attachment:86a5a42e-c449-4f2c-ab9e-5daab68b200a.png)
# > 출처: https://ncv.kdca.go.kr/covdash/biz/dsbd/covDsbdOcrn.do

# %% [markdown]
# > **어떠한 경향을 나타내고 비교할 데이터를 더 알아봅시다.**
# > * 월에 따른 여러 지역의 강수량
# > * 연도에 따른 나라별 외국인 관광객의 수
# > * 나이에 따른 남녀의 평균 키
# >
# > **위에 소개한 예시 이외에 꺾은선 그래프로 겹쳐서 표현하면 좋을 데이터를 아랫칸에 적어봅시다.**

# %% [raw]
#       👉 (...)에 따른 (...) (...)

# %% [markdown]
# ## **2. 꺾은선 그래프 겹쳐 그리기**
#
# > `plot` 함수를 이용해 그래프를 겹쳐 그리는 방법은 크게 두가지로 나눌 수 있습니다.
# >
# > 첫번째, `plot` 함수에 두 데이터를 연달아 넣는다.
# > ①  `plt.plot(data1, data2)` 를 통해 빈 figure에 꺾은선 그래프를 2개 그릴 수 있습니다.
# > ②  `plt.show()` 를 통해 figure를 출력할 수 있습니다.
# >
# > 두번째, plot 함수를 두 번 연달아 사용한다.
# > ①  `plt.plot(data1)` 를 통해 빈 figure에 첫번째 데이터를 이용한 꺾은선 그래프를 그릴 수 있습니다.
# > ②  `plt.plot(data2)` 를 통해 figure에 두번째 데이터를 이용한 꺾은선 그래프를 추가해서 그릴 수 있습니다.
# > ③  `plt.show()` 를 통해 figure를 출력할 수 있습니다.

# %% [markdown]
# ### **(1) plot 함수에 데이터 여러개 연달아 넣는 방법**
#
# > List 형태의 데이터를 이용하여 `plot` 함수로 여러개의 꺾은선 그래프로 나타내는 방법을 설명하겠습니다.
# >
# > `plt.plot(List_X1, List_Y1, List_X2, List_Y2)`
# > : List_X1에 따른 List_Y1, List_X2에 따른 List_Y2 데이터를 꺾은선 그래프로 겹쳐서 그림
# >
# > `plt.plot(List_X1, List_Y1, '1st-line-style', List_X2, List_Y2, '2nd-line-style')`
# > : 선의 스타일을 구분하고 싶다면 각 데이터 뒤에 선 스타일을 지정
# >(`'o-'`: 점과 실선, `'*-'`: 별과 실선, `'--'`: 점선)
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %%
# 예제 1: 함수에 여러 데이터 연달아 넣어 꺾은선 그래프 겹쳐그리기

X1 = ['1일', '2일', '3일', '4일', '5일', '6일', '7일']
Y1 = [50, 120, 36, 21, 50, 19, 95]

X2 = ['2일', '3일', '4일', '5일', '6일', '7일', '8일']
Y2 = [10, 48, 60, 100, 29, 57, 43]

plt.plot(X1, Y1, 'o-', X2, Y2, '*-')  # 빈 figure에 꺾은선 그래프를 연달아 그림
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="NlP3TBoTPmg" href='#jce-judge/open/NlP3TBoTPmg' target='_self'><span>꺾은선그래프 중첩 - 인생 행복&행운 그래프</span></a>

# %% [markdown]
# ### **(2) plot 함수를 연달아 사용하는 방법**
#
# > Numpy.array 형태의 데이터를 이용하여 `plot` 함수로 여러개의 꺾은선 그래프로 나타내는 방법을 설명하겠습니다.
# >
# > `plt.plot(Array_X1, Array_Y1)` : 빈 figure에 Array_X1 에 따른 Array_Y1 데이터를 꺾은선 그래프로 그림
# > `plt.plot(Array_X2, Array_Y2)` : 위의 figure에 Array_X2 에 따른 Array_Y2 데이터를 꺾은선 그래프로 겹쳐서 그림
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %%
# 예제 2: 함수를 연달아 사용해 꺾은선 그래프 겹쳐그리기

import numpy as np  # numpy 라이브러리를 사용하기 위해 np로 축약하여 불러옵니다.

X3 = np.arange(0, 7, 0.1)  # 0 부터 0.1 간격으로 7 미만까지의 수를 array에 저장
Y3 = np.sin(X3)  # X3 안의 수 x에 대해서 sin(x) 값을 array에 저장
plt.plot(X3, Y3)  # 빈 figure에 꺾은선 그래프를 그림

X4 = np.arange(0, 7, 0.1)  # 0 부터 0.1 간격으로 7 미만까지의 수를 array에 저장
Y4 = np.cos(X4)  # X4 안의 수 x에 대해서 cos(x) 값을 array에 저장
plt.plot(X4, Y4)  # 위의 figure에 꺾은선 그래프를 겹쳐서 그림

plt.show()  # figure를 출력

# %% [markdown]
# > 겹쳐진 그래프가 각각 무엇을 나타내는지 표현하고 싶다면 다음과 같이 그래프의 범례를 정할 수 있습니다.
# >
# > `plt.plot(Array_X1, Array_Y1, label='label1')` : 빈 figure에 label1 꺾은선 그래프를 그림
# > `plt.plot(Array_X2, Array_Y2, label='label2')` : 위의 figure에 label2 꺾은선 그래프를 겹쳐서 그림
# >
# > `plt.legend()`
# > : figure안에 각 그래프의 label을 적은 범례를 작성

# %%
# 예제 3: 함수를 연달아 사용해 꺾은선 그래프 겹쳐그리고 범례 추가하기

plt.plot(X3, Y3, label='sin(x)')  # 빈 figure에 sin(x) 꺾은선 그래프를 그림
plt.plot(X4, Y4, label='cos(x)')  # 위의 figure에 cos(x) 꺾은선 그래프를 겹쳐서 그림
plt.legend()  # figure의 범례를 작성 
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="nRFNXIIbcEQ" href='#jce-judge/open/nRFNXIIbcEQ' target='_self'><span>꺾은선그래프 중첩 - 2차함수와 평행이동</span></a>

# %% [markdown]
# ### **(3) 판다스 DataFrame 이용하기**
#
# > Pandas.DataFrame 형태의 데이터를 다음과 같이 `plot` 함수로 여러개의 겹쳐 꺾은선 그래프로 나타낼 수 있습니다.
# >
# > `plt.plot(DataFrame)`
# > : DataFrame.**index** 에 따른 각 열의 데이터를 꺾은선 그래프로 겹쳐서 그림
# > `plt.legend(DataFrame.columns)`
# > : 각 열의 이름으로 범례를 작성
# >
# > 그래프를 출력하기 위해서는 반드시 다음 코드를 연이어 실행해야합니다.
# > `plt.show()`

# %% [markdown]
# > **2022서울강수량.csv** 파일에는 2022년 모든 날짜의 서울지역 강수량이 저장되어 있습니다.
# >
# > 그리고 다음은 2022년 제주지역 월 별 강수량이 저장된 리스트입니다.
# > `제주의월강수량 = [33.6, 25.1, 96.1, 84, 9.1, 143.6, 149, 124.3, 265.8, 22.1, 87.8, 35.3]`
# >
# > 두 데이터를 이용하여 서울지역과 제주지역의 월 강수량을 꺾은선 그래프로 그려봅시다.
# > 그리고 두 지역의 강수량 경향성을 비교해봅시다.

# %%
# 예제 4: csv 파일을 읽어서 데이터 가져와서 월에 따른 총 강수량 계산하기

서울의강수량 = pd.read_csv("https://tmn-bucket-materials-all.s3.ap-northeast-2.amazonaws.com/data/2022%EC%84%9C%EC%9A%B8%EA%B0%95%EC%88%98%EB%9F%89.csv", index_col=0)
서울의월강수량 = 서울의강수량.sum()  # 행의 방향으로 모두 더함
서울의월강수량
# Out:
# 1월       6.5
# 2월       4.7
# 3월     102.6
# 4월      20.4
# 5월       7.5
# 6월     392.8
# 7월     252.3
# 8월     564.8
# 9월     201.5
# 10월    124.1
# 11월     84.5
# 12월     13.6
# dtype: float64

# %%
# 예제 5: 서울, 제주의 월에 따른 총 강수량으로 데이터프레임 만들기

제주의월강수량 = [33.6, 25.1, 96.1, 84, 9.1, 143.6, 149, 124.3, 265.8, 22.1, 87.8, 35.3]

# 서울, 제주 열에 각 지역의 월 강수량을 담은 데이터프레임 생성
월강수량 = pd.DataFrame(index=서울의월강수량.index, data={'서울': 서울의월강수량, '제주': 제주의월강수량})

월강수량
# Out:
#         서울     제주
# 1월     6.5   33.6
# 2월     4.7   25.1
# 3월   102.6   96.1
# 4월    20.4   84.0
# 5월     7.5    9.1
# 6월   392.8  143.6
# 7월   252.3  149.0
# 8월   564.8  124.3
# 9월   201.5  265.8
# 10월  124.1   22.1
# 11월   84.5   87.8
# 12월   13.6   35.3

# %%
# 예제 6: Pandas.DataFrame 데이터로 여러개 꺾은선 그래프 겹쳐서 그리기

plt.plot(월강수량, 'o-')  # 빈 figure에 꺾은선 그래프를 그림
plt.title("2022년 서울, 제주의 월 강수량")  # figure의 제목을 작성 
plt.legend(월강수량.columns)  # figure의 범례를 작성 
plt.show()  # figure를 출력

# %% [markdown]
# #### <연습문제>
#
# <a class="jcecodle-mk jcecodle-mk__problem-chip" data-problem-id="cEo1FqOVNNs" href='#jce-judge/open/cEo1FqOVNNs' target='_self'><span>꺾은선그래프 중첩 - 비행기 승객수</span></a>
